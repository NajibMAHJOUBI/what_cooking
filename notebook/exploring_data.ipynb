# %%
import os
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
path = "../data"

# %%
train = pd.read_json(os.path.join(path, "train.json"))

# %%
train.head()
# Out:
#        cuisine     id                                        ingredients
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
print("Train shape: {0}".format(train.shape))
print("Number of unique Id: {0}".format(len(train["id"].unique())))
print("Number of unique cuisine: {0}".format(len(train["cuisine"].unique())))
# Out:
# Train shape: (39774, 3)
# Number of unique Id: 39774
# Number of unique cuisine: 20

# %%
cuisine_count = train["cuisine"].value_counts().to_dict().items()
cuisine_count.sort(key=lambda p: p[1], reverse=True)
cuisine_count
# Out:
# [(u'italian', 7838),
#  (u'mexican', 6438),
#  (u'southern_us', 4320),
#  (u'indian', 3003),
#  (u'chinese', 2673),
#  (u'french', 2646),
#  (u'cajun_creole', 1546),
#  (u'thai', 1539),
#  (u'japanese', 1423),
#  (u'greek', 1175),
#  (u'spanish', 989),
#  (u'korean', 830),
#  (u'vietnamese', 825),
#  (u'moroccan', 821),
#  (u'british', 804),
#  (u'filipino', 755),
#  (u'irish', 667),
#  (u'jamaican', 526),
#  (u'russian', 489),
#  (u'brazilian', 467)]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 10))
count = map(lambda p: p[1], cuisine_count)
ticks = map(lambda p: p[0], cuisine_count)
ind = np.arange(len(ticks))
width = 0.35
ax.bar(ind, count);
ax.set_ylabel("Count");
ax.set_xlabel("Cuisine");
ax.set_title("Count by cuisine");
ax.set_xticks(ind);
ax.set_xticklabels(ticks, rotation=45);

# %%
words = reduce(lambda x,y: x+y, list(train["ingredients"].values))
words_count = Counter(words).items()

# %%
print("Numer of distinct words or expression: {0}".format(len(words_count)))
# Out:
# Counter({u'low-sodium fat-free chicken broth': 22,
#          u'sweetened coconut': 3,
#          u'tamarind': 39,
#          u'sushi nori': 5,
#          u'toasted pine nuts': 39,
#          u'baking chocolate': 3,
#          u'red cabbage': 134,
#          u'asian': 1,
#          u'chicken flavor stuffing mix': 2,
#          u'cummin': 2,
#          u'tandoori spices': 19,
#          u'bucatini': 16,
#          u'black garlic': 1,
#          u'organic butter': 1,
#          u'blackberries': 91,
#          u'reduced fat italian dressing': 2,
#          u'egg roll wrappers': 57,
#          u'pancetta': 177,
#          u'bottled low sodium salsa': 1,
#          u'vegan parmesan cheese': 4,
#          u'mackerel': 5,
#          u'large curd cottage cheese': 5,
#          u'cubed pancetta': 1,
#          u'whole wheat pizza crust': 3,
#          u'achiote paste': 11,
#          u'clam sauce': 1,
#          u'citrus': 2,
# ...
